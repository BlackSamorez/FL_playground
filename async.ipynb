# %%
import torch
import MiniFL as mfl

# %%
NUM_CLIENTS = 10

# %%
def get_task():
    return mfl.tasks.create_worst_case_tridiagonal_quadratics(
        num_clients=NUM_CLIENTS,
        size=4,
    )

# %%
GD_STEPS = 100

master_fn, client_fns = get_task()

master, clients = mfl.algorithms.get_gd_master_and_clients(
    master_fn=master_fn,
    client_fns=client_fns,
    gamma_multiplier=1,
)

GD_METRICS = await mfl.algorithms.run_algorithm(master, clients, GD_STEPS)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 11
#       3 master_fn, client_fns = get_task()
#       5 master, clients = mfl.algorithms.get_gd_master_and_clients(
#       6     master_fn=master_fn,
#       7     client_fns=client_fns,
#       8     gamma_multiplier=1,
#       9 )
# ---> 11 GD_METRICS = mfl.algorithms.run_algorithm(master, clients, GD_STEPS)
#
# File ~/MiniFL/src/MiniFL/algorithms/interfaces.py:59, in run_algorithm(master, clients, num_steps)
#      57     tasks.append(loop.create_task(run_client_(num_steps, client)))
#      58 tasks.append(loop.create_task(run_master_(num_steps, master, master_metrics)))
# ---> 59 asyncio.run(tasks)
#      61 return master_metrics
#
# File ~/MiniFL/.conda/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
# 100%|██████████| 100/100 [00:00<00:00, 109.22it/s]

# %%
import matplotlib.pyplot as plt

plt.plot([metrics.total_bits_received for metrics in GD_METRICS], [metrics.value for metrics in GD_METRICS], label="GD")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot([metrics.total_bits_received for metrics in GD_METRICS], [metrics.value for metrics in GD_METRICS], label="GD")
#
# NameError: name 'GD_METRICS' is not defined
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:01<00:00, 55.70it/s]
